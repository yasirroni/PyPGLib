# %%
import julia

julia.install(quiet=True)

# %%
import csv
import glob
import json
import os
import time

import numpy as np
import pandas as pd
from julia import Main
from matpower import start_instance
from matpowercaseframes.constants import COLUMNS

from pypglib import PATH_PYPGLIB

# %%
Main.eval("""
    cd("../../PowerModels.jl")
    using Pkg
    Pkg.activate(".")
    Pkg.instantiate()
""")
Main.eval("""
    using PowerModels
    using Ipopt
    using JuMP
""")
Main.eval("""
    nlp_solver = JuMP.optimizer_with_attributes(
        Ipopt.Optimizer,
        "tol" => 1e-6,
        "print_level" => 0
    )
""")
# Out:
#   Activating project at `~/Documents/Git/PowerModels.jl`
# <PyCall.jlwrap MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.RawOptimizerAttribute("tol") => 1.0e-6, MathOptInterface.RawOptimizerAttribute("print_level") => 0])>

# %%
output_dir = "../bench"
output_dir_opf = os.path.join(output_dir, "opf")

os.makedirs(output_dir_opf, exist_ok=True)

# %%
m = start_instance()

# %%
def dump_sol_to_json(sol, output_dir, file_name):
    def convert_ndarray(obj):
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        raise TypeError(f"Object of type {type(obj)} is not JSON serializable")

    json_file_path = os.path.join(output_dir, f"{file_name}.json")

    with open(json_file_path, "w") as json_file:
        json.dump(sol, json_file, indent=4, default=convert_ndarray)


def extract_sol(mpc, m):
    # NOTE: too big if pull rundcopf data
    #   m.eval("_r1.raw = rmfield(_r1.raw, 'task');")
    #   m.eval("_r1 = rmfield(_r1, 'om');")
    #   sol = m.pull("_r1")

    sol = {
        "baseMVA": mpc.baseMVA,
        "version": mpc.version,
        "bus": m.eval("_r1.bus;", verbose=False),
        "gen": m.eval("_r1.gen;", verbose=False),
        "branch": m.eval("_r1.branch;", verbose=False),
        "gencost": mpc.gencost,
        "success": m.eval("_r1.success;", verbose=False),
    }
    return sol


def extract_sol_pm(mpc, result_mpc_pm):
    sol = {
        "baseMVA": mpc.baseMVA,
        "version": mpc.version,
        "bus": mpc.bus,
        "gen": mpc.gen,
        "branch": mpc.branch,
        "gencost": mpc.gencost,
        "success": result_mpc_pm,
    }
    sorted_keys = sorted(result_mpc_pm["solution"]["bus"].keys())
    va = np.array([result_mpc_pm["solution"]["bus"][key]["va"] for key in sorted_keys])
    vm = np.array([result_mpc_pm["solution"]["bus"][key]["vm"] for key in sorted_keys])
    sorted_keys = sorted(result_mpc_pm["solution"]["gen"].keys())
    pg = (
        np.array([result_mpc_pm["solution"]["gen"][key]["pg"] for key in sorted_keys])
        * result_mpc_pm["solution"]["baseMVA"]
    )
    qg = (
        np.array([result_mpc_pm["solution"]["gen"][key]["qg"] for key in sorted_keys])
        * result_mpc_pm["solution"]["baseMVA"]
    )
    sol["gen"][:, 1] = pg
    sol["gen"][:, 2] = qg
    sol["bus"][:, 7] = vm
    sol["bus"][:, 8] = va
    return sol


def run_ed(sol, mpopt):
    # TODO: check at least voltages and power constraints
    if sol["success"] == 1:
        sol_ed = m.runpf(sol, mpopt, verbose=False)
        if sol_ed["success"] == 1:
            status = "Success"
            # NOTE: 1 is index for PG
            cost = m.totcost(sol_ed["gencost"], sol_ed["gen"][:, [1]]).sum()
        else:
            status = "Not Converge"
            cost = "--"
    else:
        sol_ed = {}
        status = "Infeasible"
        cost = "inf"  # Infeasible solution
    return sol_ed, status, cost


def write_to_csv(data_dict, csv_file_path, fieldnames):
    with open(csv_file_path, mode="a", newline="") as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        writer.writerow(data_dict)


def write_acopf_matpower_to_csv(
    file_name, status, cost, python_time_perf, csv_file_path, fieldnames
):
    data_dict = {
        "file_name": file_name,
        "matpower-pip_acopf_status": status,
        "matpower-pip_acopf_cost": cost,
        "matpower-pip_acopf_python_time_perf": python_time_perf,
    }
    write_to_csv(data_dict, csv_file_path, fieldnames)


def write_dcopf_matpower_to_csv(
    file_name, status, cost, python_time_perf, csv_file_path, fieldnames
):
    data_dict = {
        "file_name": file_name,
        "matpower-pip_dcopf_status": status,
        "matpower-pip_dcopf_cost": cost,
        "matpower-pip_dcopf_python_time_perf": python_time_perf,
    }
    write_to_csv(data_dict, csv_file_path, fieldnames)


def write_acopf_powermodels_to_csv(
    file_name, status, cost, python_time_perf, csv_file_path, fieldnames
):
    data_dict = {
        "file_name": file_name,
        "powermodels_acopf_status": status,
        "powermodels_acopf_cost": cost,
        "powermodels_acopf_python_time_perf": python_time_perf,
    }
    write_to_csv(data_dict, csv_file_path, fieldnames)


def julia_script_mpc_to_pm_data():
    return """
        function convert_matrix_to_vector_of_reals(value::Any)
            if isa(value, AbstractMatrix)
                return [Vector(row) for row in eachrow(value)]
            else
                return value
            end
        end

        function convert_dict_value_matrix_to_vector_of_reals(data::Dict)
            for (key, value) in data
                data[key] = convert_matrix_to_vector_of_reals(value)
            end
            return data
        end

        function convert_python_to_matlab_data(dict::Dict{Any, Any})
            new_dict = Dict{String, Any}()
            for (key, value) in dict
                new_dict[string(key)] = convert_matrix_to_vector_of_reals(value)
            end
            return new_dict
        end

        matlab_data = convert_python_to_matlab_data(matlab_data)
        pm_data = PowerModels.parse_matpower(matlab_data, validate=true)
    """

# %%
# file_name, status, cost, python_time_perf, csv_file_path, fieldnames
# Out:
# ('pglib_opf_case4837_goc.m',
#  'Infeasible',
#  'inf',
#  22.11337129200001,
#  '../bench/opf/powermodels_acopf_benchmark_results.csv',
#  ['file_name',
#   'powermodels_acopf_status',
#   'powermodels_acopf_cost',
#   'powermodels_acopf_python_time_perf'])

# %%
# (
#     file_name,
#     mpc['gen'].shape,
#     mpc_pm['mpc.gen'].shape,
#     len(pm_data['gen']),
#     len(result_mpc_pm['solution']['gen']
# )
# Out:
# ('pglib_opf_case2746wop_k.m', (514, 10), (514, 10), 514, 431)

# %%
N_WORKERS = 2  # multithreading
opf_dir = os.path.join(PATH_PYPGLIB, "opf")  # 198 cases
mpopt = m.mpoption("verbose", 0, "out.all", 0)
m.push("_mpopt", mpopt)

csv_file_path = os.path.join(output_dir_opf, "powermodels_acopf_benchmark_results.csv")
fieldnames = [
    "file_name",
    "powermodels_acopf_status",
    "powermodels_acopf_cost",
    "powermodels_acopf_python_time_perf",
]

# create results and check already run case
if not os.path.isfile(csv_file_path):
    with open(csv_file_path, mode="w", newline="") as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        writer.writeheader()
df_results = pd.read_csv(csv_file_path)
file_names_m = df_results["file_name"].tolist()

file_paths = list(glob.glob(os.path.join(opf_dir, "**", "*.m"), recursive=True))
for file_path in file_paths:
    # # NOTE: this part for debug only
    # case9_path = os.path.join(PATH_MATPOWER, 'data', 'case9.m')
    # file_path = case9_path

    file_name = os.path.basename(file_path)
    if file_name in file_names_m:
        continue
        # return

    mpc = m.loadcase(file_path)
    # try:
    start_time_perf = time.perf_counter()
    mpc_pm = {("mpc." + key, value) for (key, value) in mpc.items()}
    Main.matlab_data = mpc_pm
    pm_data = Main.eval(julia_script_mpc_to_pm_data())
    result_mpc_pm = Main.eval("result = solve_opf(pm_data, ACPPowerModel, nlp_solver)")

    sol = extract_sol_pm(mpc, result_mpc_pm)
    # sol = extract_sol(mpc, m)  # matpower
    python_time_perf = time.perf_counter() - start_time_perf

    sol_ed, status, cost = run_ed(sol, mpopt)
    # except Oct2PyError as e:
    #     print(e)
    #     print(file_name)
    #     sol = {}
    #     status = "Error"
    #     cost = "Err"
    #     python_time_perf = np.inf

    # NOTE: json is too big, 5 MB for single case
    # dump_sol_to_json(sol, output_dir_opf, file_name)  # too big

    try:
        # NOTE: refactored form using cf to make it faster
        base_name = os.path.splitext(os.path.basename(file_name))[0]
        n_cols = sol["gen"].shape[1]
        columns = COLUMNS.get("gen", list(range(n_cols)))
        columns = columns[:n_cols]
        gen_csv_path = os.path.join(
            output_dir_opf, f"{base_name}_powermodels_acopf.gen.csv"
        )
        with open(gen_csv_path, mode="w", newline="") as file:
            writer = csv.writer(file)
            writer.writerow(columns)  # Write the header
            writer.writerows(sol["gen"])  # Write the data rows

    except (AttributeError, KeyError):
        # errors
        pass

    write_acopf_powermodels_to_csv(
        file_name, status, cost, python_time_perf, csv_file_path, fieldnames
    )
    break
# Out:
# [warn | PowerModels]: no active generators found at bus 1110, updating to bus type from 2 to 1
# [warn | PowerModels]: active generators found at bus 2733, updating to bus type from 1 to 2
# [warn | PowerModels]: no active generators found at bus 116, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 147, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 1779, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 958, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 809, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 2002, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 2729, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 132, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 1352, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 2711, updating to bus type from 2 to 1
# [warn | PowerModels]: active generators found at bus 2732, updating to bus type from 1 to 2
# [warn | PowerModels]: no active generators found at bus 876, updating to bus type from 2 to 1
# [warn | PowerModels]: active generators found at bus 2734, updating to bus type from 1 to 2
# [warn | PowerModels]: no active generators found at bus 1677, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 1518, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 1415, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 760, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 792, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 2730, updating to bus type from 2 to 1
# [warn | PowerModels]: active generators found at bus 1032, updating to bus type from 1 to 2
# [warn | PowerModels]: no active generators found at bus 135, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 1112, updating to bus type from 2 to 1
# [warn | PowerModels]: active generators found at bus 2738, updating to bus type from 1 to 2
# [warn | PowerModels]: no active generators found at bus 1877, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 105, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 133, updating to bus type from 2 to 1
# [warn | PowerModels]: no active generators found at bus 903, updating to bus type from 2 to 1
# [info | PowerModels]: removing 3 cost terms from generator 306: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 407: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 1: [11278.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 54: [9243.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 101: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 371: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 41: [9712.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 464: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 65: [11601.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 475: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 447: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 335: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 362: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 505: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 491: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 326: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 299: [9952.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 168: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 159: [10205.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 403: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 228: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 332: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 190: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 227: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 270: [9531.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 476: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 223: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 453: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 88: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 467: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 297: [9952.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 26: [10535.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 289: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 250: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 77: [8922.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 230: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 24: [10535.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 449: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 394: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 258: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 328: [11601.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 204: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 387: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 23: [10535.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 160: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 416: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 450: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 149: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 359: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 59: [11601.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 184: [1.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 43: [9952.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 122: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 253: [9409.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 302: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 175: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 415: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 39: [9409.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 143: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 112: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 372: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 34: [9531.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 501: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 293: [9712.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 421: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 137: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 55: [9243.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 323: [9243.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 17: [10205.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 243: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 318: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 9: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 172: [10535.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 333: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 363: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 12: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 192: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 20: [10205.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 292: [9712.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 350: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 252: [9409.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 357: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 514: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 341: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 417: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 462: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 426: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 14: [10205.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 167: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 127: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 96: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 123: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 456: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 177: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 254: [9409.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 300: [9952.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 257: [9278.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 510: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 19: [10205.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 179: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 242: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 396: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 260: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 495: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 239: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 35: [9003.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 423: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 317: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 197: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 131: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 488: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 401: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 276: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 316: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 365: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 458: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 463: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 494: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 21: [10205.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 263: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 83: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 244: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 45: [9116.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 295: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 139: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 181: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 386: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 368: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 436: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 440: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 85: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 413: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 105: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 30: [9531.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 3: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 309: [9116.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 81: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 400: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 480: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 482: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 296: [9952.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 27: [10535.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 75: [8922.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 392: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 503: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 50: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 460: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 162: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 63: [11601.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 303: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 92: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 422: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 208: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 214: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 120: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 224: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 87: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 117: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 255: [9409.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 499: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 178: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 89: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 275: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 176: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 182: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 496: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 225: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 195: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 286: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 249: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 485: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 161: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 442: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 202: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 346: [9642.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 389: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 459: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 465: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 146: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 142: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 219: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 256: [9278.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 291: [9712.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 80: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 203: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 308: [9116.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 360: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 432: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 113: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 110: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 418: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 492: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 445: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 322: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 431: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 269: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 157: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 57: [9642.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 165: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 231: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 384: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 327: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 173: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 284: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 200: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 171: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 233: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 428: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 345: [9642.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 130: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 273: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 319: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 478: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 312: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 502: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 15: [10205.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 61: [11601.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 67: [9884.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 247: [9278.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 108: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 100: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 344: [9642.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 385: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 457: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 500: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 46: [9116.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 251: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 444: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 170: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 151: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 248: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 68: [9884.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 56: [9642.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 147: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 454: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 452: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 76: [8922.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 186: [11163.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 342: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 438: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 180: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 135: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 262: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 48: [9116.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 103: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 355: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 393: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 408: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 32: [9531.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 109: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 264: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 320: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 217: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 334: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 405: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 2: [11278.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 183: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 155: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 51: [1.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 53: [9243.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 106: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 435: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 489: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 111: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 141: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 287: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 93: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 213: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 278: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 10: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 340: [9642.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 474: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 356: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 265: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 215: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 305: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 443: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 424: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 154: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 321: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 358: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 49: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 218: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 5: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 62: [11601.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 196: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 90: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 234: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 446: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 404: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 205: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 237: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 201: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 311: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 390: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 315: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 448: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 298: [9952.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 461: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 366: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 164: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 419: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 380: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 86: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 126: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 152: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 71: [9884.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 37: [9278.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 226: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 399: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 245: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 469: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 487: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 266: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 268: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 6: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 441: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 125: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 98: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 473: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 272: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 379: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 174: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 512: Float64[]
# [info | PowerModels]: removing 3 cost terms from generato
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 41
#      38 pm_data = Main.eval(julia_script_mpc_to_pm_data())
#      39 result_mpc_pm = Main.eval("result = solve_opf(pm_data, ACPPowerModel, nlp_solver)")
# ---> 41 sol = extract_sol_pm(mpc, result_mpc_pm)
#      42 # sol = extract_sol(mpc, m)  # matpower
#      43 python_time_perf = time.perf_counter() - start_time_perf
#
# Cell In[19], line 47, in extract_sol_pm(mpc, result_mpc_pm)
#      45 pg = np.array([result_mpc_pm['solution']['gen'][key]['pg'] for key in sorted_keys]) * result_mpc_pm['solution']['baseMVA']
#      46 qg = np.array([result_mpc_pm['solution']['gen'][key]['qg'] for key in sorted_keys]) * result_mpc_pm['solution']['baseMVA']
# ---> 47 sol['gen'][:, 1] = pg
#      48 sol['gen'][:, 2] = qg
#      49 sol['bus'][:, 7] = vm
#
# ValueError: could not broadcast input array from shape (431,) into shape (514,)
# r 187: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 471: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 493: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 7: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 361: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 261: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 194: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 140: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 486: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 397: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 337: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 107: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 102: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 69: [9884.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 354: [9884.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 282: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 97: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 4: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 221: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 235: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 212: [9003.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 210: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 369: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 13: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 136: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 211: [9003.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 134: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 133: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 148: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 240: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 329: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 193: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 373: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 118: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 283: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 513: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 246: [9278.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 466: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 508: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 38: [9278.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 375: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 188: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 307: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 199: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 116: [11278.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 378: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 425: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 376: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 66: [9884.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 411: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 241: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 301: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 468: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 18: [10205.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 455: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 132: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 29: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 477: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 78: [8922.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 470: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 388: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 367: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 382: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 74: [9884.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 402: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 119: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 236: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 42: [9712.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 33: [9531.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 28: [10535.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 52: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 381: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 439: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 347: [8922.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 121: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 451: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 497: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 504: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 290: [9712.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 115: [11278.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 395: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 409: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 314: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 351: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 509: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 163: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 339: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 481: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 281: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 58: [9642.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 25: [10535.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 114: [11278.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 374: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 166: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 31: [9531.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 274: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 370: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 206: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 279: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 280: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 313: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 364: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 484: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 44: [9116.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 169: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 129: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 189: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 150: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 259: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 94: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 352: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 288: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 412: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 429: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 430: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 479: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 99: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 207: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 47: [9116.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 330: [1.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 73: [9884.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 82: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 285: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 310: [9116.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 433: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 406: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 79: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 437: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 216: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 377: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 84: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 325: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 511: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 104: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 124: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 238: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 209: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 185: [11163.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 267: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 70: [9884.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 410: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 427: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 507: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 349: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 391: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 191: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 8: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 304: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 338: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 198: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 64: [11601.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 222: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 343: [9642.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 91: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 60: [11601.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 158: [10205.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 156: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 229: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 348: [8922.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 498: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 144: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 420: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 220: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 22: [10535.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 11: [7609.999999999999, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 271: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 383: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 434: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 324: [9243.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 483: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 277: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 398: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 16: [10205.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 490: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 331: [1.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 506: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 40: [9409.0, 0.0]
# [info | PowerModels]: removing 1 cost terms from generator 72: [9884.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 128: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 472: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 145: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 36: [9003.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 95: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 138: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 336: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 414: Float64[]
# [info | PowerModels]: removing 1 cost terms from generator 294: [9952.0, 0.0]
# [info | PowerModels]: removing 3 cost terms from generator 353: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 232: Float64[]
# [info | PowerModels]: removing 3 cost terms from generator 153: Float64[]

# %%
# N_WORKERS = 2  # multithreading
# PG = 1  # index for PG
# opf_dir = os.path.join(PATH_PYPGLIB, "opf")  # 198 cases
# mpopt = m.mpoption("verbose", 0, "out.all", 0)
# m.push("_mpopt", mpopt)

# csv_file_path = os.path.join(output_dir_opf, "dcopf_benchmark_results.csv")
# fieldnames = [
#     "file_name",
#     "matpower-pip_dcopf_status",
#     "matpower-pip_dcopf_cost",
#     "matpower-pip_dcopf_python_time_perf",
# ]

# # create results and check already run case
# if not os.path.isfile(csv_file_path):
#     with open(csv_file_path, mode="w", newline="") as csv_file:
#         writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
#         writer.writeheader()
# df_results = pd.read_csv(csv_file_path)
# file_names_m = df_results["file_name"].tolist()

# file_paths = list(glob.glob(os.path.join(opf_dir, "**", "*.m"), recursive=True))
# for file_path in file_paths:
#     # # NOTE: this part for debug only
#     # case9_path = os.path.join(PATH_MATPOWER, 'data', 'case9.m')
#     # file_path = case9_path

#     file_name = os.path.basename(file_path)
#     if file_name in file_names_m:
#         continue
#         # return

#     mpc = m.loadcase(file_path)
#     try:
#         start_time_perf = time.perf_counter()
#         m.push("_mpc", mpc)
#         m.eval("_r1 = rundcopf(_mpc, _mpopt);", verbose=False)
#         sol = extract_sol(mpc, m)
#         python_time_perf = time.perf_counter() - start_time_perf

#         sol_ed, status, cost = run_ed(sol, mpopt)
#     except Oct2PyError as e:
#         print(e)
#         print(file_name)
#         sol = {}
#         status = "Error"
#         cost = "Err"
#         python_time_perf = np.inf

#     # NOTE: json is too big, 5 MB for single case
#     # dump_sol_to_json(sol, output_dir_opf, file_name)  # too big

#     try:
#         # NOTE: refactored form using cf to make it faster
#         base_name = os.path.splitext(os.path.basename(file_name))[0]
#         n_cols = sol["gen"].shape[1]
#         columns = COLUMNS.get("gen", list(range(n_cols)))
#         columns = columns[:n_cols]
#         gen_csv_path = os.path.join(output_dir_opf, f"{base_name}_dcopf.gen.csv")
#         with open(gen_csv_path, mode="w", newline="") as file:
#             writer = csv.writer(file)
#             writer.writerow(columns)  # Write the header
#             writer.writerows(sol["gen"])  # Write the data rows

#     except (AttributeError, KeyError):
#         # errors
#         pass

#     write_dcopf_matpower_to_csv(
#         file_name, status, cost, python_time_perf, csv_file_path, fieldnames
#     )
# Out:
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6470_rte.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6515_rte.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case500_goc.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case2868_rte.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case2848_rte.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6468_rte.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6495_rte.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case1888_rte.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case1951_rte.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6468_rte__sad.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6495_rte__sad.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case1888_rte__sad.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6470_rte__sad.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6515_rte__sad.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6515_rte__api.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case1888_rte__api.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6470_rte__api.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case2848_rte__api.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6495_rte__api.m
# Octave evaluation error:
# error: ij(_,1): out of bound 0 (dimensions are 1x0)
# error: called from:
#     update_z at line 86, column 21
#     convert_x_m2n at line 36, column 20
#     network_model_x_soln at line 487, column 47
#     network_model_x_soln at line 910, column 16
#     network_model_x_soln at line 186, column 16
#     network_model_update at line 929, column 13
#     run at line 196, column 28
#     runpf at line 166, column 5
# pglib_opf_case6468_rte__api.m

# %%
os.makedirs(output_dir_opf, exist_ok=True)
df_results = pd.read_csv(csv_file_path)

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)
pd.set_option("display.width", 1000)

print(df_results)
# Out:
#                                file_name matpower-pip_dcopf_status matpower-pip_dcopf_cost  matpower-pip_dcopf_python_time_perf
# 0               pglib_opf_case4837_goc.m                   Success       893816.6359427541                            15.193566
# 1              pglib_opf_case2746wop_k.m                   Success      1207752.8238761476                            10.871248
# 2               pglib_opf_case4601_goc.m                Infeasible                     inf                            15.504618
# 3               pglib_opf_case4917_goc.m                Infeasible                     inf                            14.942911
# 4               pglib_opf_case2746wp_k.m                   Success      1627996.7513315084                            10.431077
# 5               pglib_opf_case197_snem.m                   Success       1.508463783081175                             9.754716
# 6           pglib_opf_case13659_pegase.m              Not Converge                      --                            41.387278
# 7              pglib_opf_case10000_goc.m                Infeasible                     inf                            20.227374
# 8               pglib_opf_case6470_rte.m                     Error                     Err                                  inf
# 9               pglib_opf_case6515_rte.m                     Error                     Err                                  inf
# 10              pglib_opf_case3375wp_k.m                   Success       7420610.136733997                            11.226115
# 11                  pglib_opf_case60_c.m                   Success       95057.74387033265                             9.739366
# 12               pglib_opf_case500_goc.m                     Error                     Err                                  inf
# 13          pglib_opf_case162_ieee_dtc.m                   Success       102293.4388862272                             9.780455
# 14              pglib_opf_case118_ieee.m                   Success       97887.62741986552                             9.760828
# 15             pglib_opf_case2737sop_k.m                   Success          777324.6347588                            10.536700
# 16        pglib_opf_case10192_epigrids.m                Infeasible                     inf                            23.108685
# 17             pglib_opf_case89_pegase.m                   Success      105660.32267946532                             9.752624
# 18              pglib_opf_case2868_rte.m                     Error                     Err                                  inf
# 19              pglib_opf_case3120sp_k.m                   Success       2141676.814112272                            11.055372
# 20        pglib_opf_case78484_epigrids.m                Infeasible                     inf                            11.369351
# 21              pglib_opf_case2312_goc.m                Infeasible                     inf                            11.773038
# 22              pglib_opf_case3970_goc.m                Infeasible                     inf                            14.842023
# 23              pglib_opf_case2736sp_k.m                   Success      1304844.2937414593                            10.477524
# 24           pglib_opf_case9241_pegase.m              Not Converge                      --                            24.106174
# 25              pglib_opf_case3012wp_k.m                   Success      2592109.5873425584                            10.835646
# 26              pglib_opf_case4619_goc.m                Infeasible                     inf                            16.217392
# 27             pglib_opf_case240_pserc.m                   Success       3331820.825122793                             9.751748
# 28             pglib_opf_case19402_goc.m                Infeasible                     inf                            37.923862
# 29        pglib_opf_case20758_epigrids.m                   Success      2578398.1122587672                            35.282636
# 30             pglib_opf_case4661_sdet.m                   Success      2255740.0539984033                            14.372502
# 31         pglib_opf_case5658_epigrids.m                Infeasible                     inf                             9.959657
# 32                 pglib_opf_case30_as.m                   Success       814.8563708485224                             9.754313
# 33              pglib_opf_case2848_rte.m                     Error                     Err                                  inf
# 34             pglib_opf_case200_activ.m                   Success      34744.409554567814                             9.787561
# 35              pglib_opf_case2742_goc.m                   Success      259843.32601083792                            12.211149
# 36              pglib_opf_case6468_rte.m                     Error                     Err                                  inf
# 37           pglib_opf_case8387_pegase.m                   Success      2609768.6913017035                            22.843044
# 38              pglib_opf_case6495_rte.m                     Error                     Err                                  inf
# 39              pglib_opf_case588_sdet.m                   Success      317091.26392882515                             9.784268
# 40           pglib_opf_case24_ieee_rts.m                   Success       63680.12071287247                             9.763387
# 41              pglib_opf_case2000_goc.m                   Success       957747.4753863215                            10.581781
# 42             pglib_opf_case30000_goc.m                Infeasible                     inf                            36.787683
# 43             pglib_opf_case24464_goc.m                Infeasible                     inf                            39.951129
# 44               pglib_opf_case57_ieee.m                   Success       36325.84226684593                             9.762441
# 45              pglib_opf_case2383wp_k.m                   Success      1876118.3650128632                            10.287197
# 46                pglib_opf_case3_lmbd.m                   Success       5772.037532325129                             9.742141
# 47              pglib_opf_case3022_goc.m                Infeasible                     inf                            13.098394
# 48             pglib_opf_case10480_goc.m                Infeasible                     inf                            25.053185
# 49               pglib_opf_case179_goc.m                   Success        760497.458910479                             9.761019
# 50               pglib_opf_case14_ieee.m                   Success      2201.3240823320007                             9.762146
# 51              pglib_opf_case1888_rte.m                     Error                     Err                                  inf
# 52           pglib_opf_case2869_pegase.m                Infeasible                     inf                             9.819115
# 53               pglib_opf_case30_ieee.m                   Success       7852.165843315575                             9.745503
# 54               pglib_opf_case39_epri.m                   Success      137450.35835302967                             9.743402
# 55              pglib_opf_case4020_goc.m                Infeasible                     inf                            15.607178
# 56           pglib_opf_case1354_pegase.m                   Success      1231186.3402379374                            10.055179
# 57              pglib_opf_case9591_goc.m                Infeasible                     inf                            22.581046
# 58              pglib_opf_case300_ieee.m              Not Converge                      --                             9.774677
# 59           pglib_opf_case73_ieee_rts.m                   Success       191024.0730150293                             9.789889
# 60             pglib_opf_case2853_sdet.m                   Success      2059898.8121028212                            11.413311
# 61         pglib_opf_case7336_epigrids.m                Infeasible                     inf                             9.866196
# 62             pglib_opf_case1803_snem.m              Not Converge                      --                            10.050797
# 63               pglib_opf_case793_goc.m                Infeasible                     inf                            10.172840
# 64                 pglib_opf_case5_pjm.m                   Success      17680.981014803532                             9.746639
# 65              pglib_opf_case1951_rte.m                     Error                     Err                                  inf
# 66         pglib_opf_case3120sp_k__sad.m                Infeasible                     inf                            11.145376
# 67      pglib_opf_case2869_pegase__sad.m                Infeasible                     inf                             9.832976
# 68          pglib_opf_case30_ieee__sad.m                   Success        7852.16584331557                             9.753341
# 69          pglib_opf_case39_epri__sad.m                Infeasible                     inf                             9.756751
# 70         pglib_opf_case3022_goc__sad.m                Infeasible                     inf                            12.969321
# 71      pglib_opf_case9241_pegase__sad.m                Infeasible                     inf                            21.828550
# 72        pglib_opf_case10000_goc__sad.m                Infeasible                     inf                            20.389328
# 73         pglib_opf_case4601_goc__sad.m                Infeasible                     inf                            15.301415
# 74         pglib_opf_case6468_rte__sad.m                     Error                     Err                                  inf
# 75         pglib_opf_case2383wp_k__sad.m                Infeasible                     inf                            10.316080
# 76        pglib_opf_case200_activ__sad.m                Infeasible                     inf                             9.770844
# 77         pglib_opf_case300_ieee__sad.m              Not Converge                      --                             9.772686
# 78         pglib_opf_case4837_goc__sad.m                Infeasible                     inf                            15.457275
# 79      pglib_opf_case73_ieee_rts__sad.m                Infeasible                     inf                             9.881749
# 80          pglib_opf_case179_goc__sad.m                Infeasible                     inf                             9.718048
# 81         pglib_opf_case2312_goc__sad.m                Infeasible                     inf                            12.173658
# 82     pglib_opf_case162_ieee_dtc__sad.m                   Success      104862.91479594655                             9.775615
# 83        pglib_opf_case10480_goc__sad.m                Infeasible                     inf                            24.981062
# 84         pglib_opf_case3375wp_k__sad.m                   Success       7420707.150765193                            11.307905
# 85        pglib_opf_case89_pegase__sad.m                Infeasible                     inf                             9.765961
# 86            pglib_opf_case5_pjm__sad.m                Infeasible                     inf                             9.756279
# 87        pglib_opf_case2737sop_k__sad.m                Infeasible                     inf                            10.618748
# 88        pglib_opf_case30000_goc__sad.m                Infeasible                     inf                            37.604444
# 89      pglib_opf_case1354_pegase__sad.m                Infeasible                     inf                            10.004856
# 90         pglib_opf_case197_snem__sad.m                   Success       528.5774177926224                             9.758236
# 91         pglib_opf_case6495_rte__sad.m                     Error                     Err                                  inf
# 92        pglib_opf_case2746wop_k__sad.m                Infeasible                     inf                            10.474788
# 93         pglib_opf_case4020_goc__sad.m                Infeasible                     inf                            15.598400
# 94         pglib_opf_case118_ieee__sad.m                Infeasible                     inf                             9.765940
# 95         pglib_opf_case2868_rte__sad.m                Infeasible                     inf                            10.953967
# 96        pglib_opf_case24464_goc__sad.m                Infeasible                     inf                            40.219067
# 97      pglib_opf_case24_ieee_rts__sad.m                Infeasible                     inf                             9.798159
# 98         pglib_opf_case2000_goc__sad.m                Infeasible                     inf                            12.052861
# 99          pglib_opf_case14_ieee__sad.m                Infeasible                     inf                             9.766623
# 100       pglib_opf_case240_pserc__sad.m                Infeasible                     inf                             9.774592
# 101         pglib_opf_case500_goc__sad.m                Infeasible                     inf                            10.295863
# 102       pglib_opf_case2853_sdet__sad.m                Infeasible                     inf                            11.548250
# 103     pglib_opf_case8387_pegase__sad.m                Infeasible                     inf                            18.025329
# 104        pglib_opf_case1951_rte__sad.m                Infeasible                     inf                            10.306973
# 105          pglib_opf_case3_lmbd__sad.m                   Success       5944.765658620352                             9.758829
# 106         pglib_opf_case793_goc__sad.m                Infeasible                     inf                            10.606743
# 107        pglib_opf_case1888_rte__sad.m                     Error                     Err                                  inf
# 108        pglib_opf_case588_sdet__sad.m                Infeasible                     inf                             9.793449
# 109        pglib_opf_case2736sp_k__sad.m                Infeasible                     inf                            10.552036
# 110       pglib_opf_case1803_snem__sad.m                Infeasible                     inf                            10.008259
# 111        pglib_opf_case6470_rte__sad.m                     Error                     Err                                  inf
# 112        pglib_opf_case2848_rte__sad.m                Infeasible                     inf                            10.803621
# 113  pglib_opf_case10192_epigrids__sad.m                Infeasible                     inf                            23.334594
# 114        pglib_opf_case2742_goc__sad.m                   Success      259843.32601081033                            12.254414
# 115        pglib_opf_case9591_goc__sad.m                Infeasible                     inf                            22.616101
# 116        pglib_opf_case4619_goc__sad.m                Infeasible                     inf                            16.256610
# 117        pglib_opf_case3012wp_k__sad.m                Infeasible                     inf                            10.941831
# 118  pglib_opf_case78484_epigrids__sad.m                Infeasible                     inf                            11.440949
# 119  pglib_opf_case20758_epigrids__sad.m                Infeasible                     inf                            35.517969
# 120            pglib_opf_case60_c__sad.m                Infeasible                     inf                             9.758379
# 121         pglib_opf_case57_ieee__sad.m                   Success      38666.917546731376                             9.770255
# 122           pglib_opf_case30_as__sad.m                Infeasible                     inf                             9.761380
# 123    pglib_opf_case13659_pegase__sad.m                Infeasible                     inf                            35.456164
# 124       pglib_opf_case4661_sdet__sad.m                Infeasible                     inf                            13.464478
# 125        pglib_opf_case3970_goc__sad.m                Infeasible                     inf                            14.873232
# 126        pglib_opf_case4917_goc__sad.m                Infeasible                     inf                            13.180748
# 127        pglib_opf_case6515_rte__sad.m                     Error                     Err                                  inf
# 128   pglib_opf_case7336_epigrids__sad.m                Infeasible                     inf                             9.840212
# 129       pglib_opf_case19402_goc__sad.m                Infeasible                     inf                            38.015415
# 130   pglib_opf_case5658_epigrids__sad.m                Infeasible                     inf                             9.875966
# 131        pglib_opf_case2746wp_k__sad.m                Infeasible                     inf                            10.486689
# 132  pglib_opf_case20758_epigrids__api.m                Infeasible                     inf                            35.486579
# 133         pglib_opf_case57_ieee__api.m                   Success       36081.77180522084                             9.758595
# 134            pglib_opf_case60_c__api.m                   Success      183462.46994717576                             9.760599
# 135           pglib_opf_case30_as__api.m                   Success      3109.2348814135335                             9.771045
# 136  pglib_opf_case78484_epigrids__api.m                Infeasible                     inf                            11.479653
# 137        pglib_opf_case4917_goc__api.m                Infeasible                     inf                            14.669097
# 138       pglib_opf_case4661_sdet__api.m                   Success      2723258.2130235867                            14.863743
# 139    pglib_opf_case13659_pegase__api.m              Not Converge                      --                            46.085932
# 140        pglib_opf_case3970_goc__api.m                Infeasible                     inf                            14.968605
# 141   pglib_opf_case7336_epigrids__api.m                Infeasible                     inf                             9.842458
# 142       pglib_opf_case19402_goc__api.m                Infeasible                     inf                            38.167309
# 143        pglib_opf_case6515_rte__api.m                     Error                     Err                                  inf
# 144   pglib_opf_case5658_epigrids__api.m                Infeasible                     inf                             9.918744
# 145        pglib_opf_case2746wp_k__api.m                   Success       616341.3733812326                            10.546801
# 146     pglib_opf_case8387_pegase__api.m                   Success        5078744.94552297                            23.508414
# 147         pglib_opf_case500_goc__api.m                Infeasible                     inf                            10.305413
# 148       pglib_opf_case2853_sdet__api.m                   Success        2482816.32241242                            11.570976
# 149         pglib_opf_case793_goc__api.m                Infeasible                     inf                            10.428820
# 150        pglib_opf_case1951_rte__api.m                Infeasible                     inf                            10.269652
# 151          pglib_opf_case3_lmbd__api.m                   Success      10722.195776922583                             9.737556
# 152       pglib_opf_case1803_snem__api.m              Not Converge                      --                            10.080257
# 153        pglib_opf_case588_sdet__api.m                   Success      401928.53154372785                             9.772185
# 154        pglib_opf_case1888_rte__api.m                     Error                     Err                                  inf
# 155        pglib_opf_case2736sp_k__api.m                   Success      1035295.4012854031                            10.620235
# 156        pglib_opf_case9591_goc__api.m                Infeasible                     inf                            22.565848
# 157        pglib_opf_case2742_goc__api.m                Infeasible                     inf                            13.355833
# 158        pglib_opf_case4619_goc__api.m                Infeasible                     inf                            16.395397
# 159        pglib_opf_case3012wp_k__api.m                   Success        970614.888988886                            11.126243
# 160        pglib_opf_case6470_rte__api.m                     Error                     Err                                  inf
# 161        pglib_opf_case2848_rte__api.m                     Error                     Err                                  inf
# 162  pglib_opf_case10192_epigrids__api.m                Infeasible                     inf                            23.576160
# 163           pglib_opf_case5_pjm__api.m                   Success       78353.66756688121                             9.752971
# 164       pglib_opf_case2737sop_k__api.m                   Success       793295.6810973831                            10.632487
# 165    pglib_opf_case162_ieee_dtc__api.m                   Success      112951.47487422946                             9.765655
# 166        pglib_opf_case2312_goc__api.m                Infeasible                     inf                            12.019589
# 167       pglib_opf_case10480_goc__api.m                Infeasible                     inf                            25.030380
# 168        pglib_opf_case3375wp_k__api.m                   Success       6392774.270947779                            11.491974
# 169       pglib_opf_case89_pegase__api.m                   Success      115892.27337594976                             9.757184
# 170     pglib_opf_case1354_pegase__api.m                   Success      1570724.9548595042                            10.030461
# 171        pglib_opf_case197_snem__api.m                   Success      15706.914095946235                             9.758447
# 172       pglib_opf_case30000_goc__api.m                Infeasible                     inf                            38.073774
# 173        pglib_opf_case4020_goc__api.m                Infeasible                     inf                            15.646591
# 174        pglib_opf_case6495_rte__api.m                     Error                     Err                                  inf
# 175       pglib_opf_case2746wop_k__api.m                   Success       558399.5468985555                            10.422518
# 176     pglib_opf_case24_ieee_rts__api.m                   Success      158714.03472938886                             9.656402
# 177       pglib_opf_case240_pserc__api.m                   Success       4686227.439462604                             9.675051
# 178         pglib_opf_case14_ieee__api.m                   Success       5119.598744332463                             9.684756
# 179        pglib_opf_case2000_goc__api.m                Infeasible                     inf                            11.195486
# 180        pglib_opf_case118_ieee__api.m                   Success       241389.4448390292                             9.701561
# 181        pglib_opf_case2868_rte__api.m                Infeasible                     inf                            10.706737
# 182       pglib_opf_case24464_goc__api.m                Infeasible                     inf                            41.159381
# 183     pglib_opf_case2869_pegase__api.m                Infeasible                     inf                             9.815017
# 184        pglib_opf_case3120sp_k__api.m                   Success      1415996.0520414277                            11.128896
# 185         pglib_opf_case39_epri__api.m                   Success      254256.35070154647                             9.722392
# 186        pglib_opf_case3022_goc__api.m                Infeasible                     inf                            12.862365
# 187         pglib_opf_case30_ieee__api.m                   Success      17031.313861261235                             9.730226
# 188       pglib_opf_case200_activ__api.m                   Success       47714.47785270598                             9.766806
# 189        pglib_opf_case2383wp_k__api.m                   Success       335308.2787041953                            10.306706
# 190        pglib_opf_case6468_rte__api.m                     Error                     Err                                  inf
# 191        pglib_opf_case300_ieee__api.m                   Success       666776.3431514301                             9.751584
# 192        pglib_opf_case4601_goc__api.m                Infeasible                     inf                            15.356251
# 193     pglib_opf_case9241_pegase__api.m              Not Converge                      --                            23.507903
# 194       pglib_opf_case10000_goc__api.m                Infeasible                     inf                            20.511890
# 195         pglib_opf_case179_goc__api.m                   Success       1825263.619463522                             9.730427
# 196        pglib_opf_case4837_goc__api.m                Infeasible                     inf                            15.580520
# 197     pglib_opf_case73_ieee_rts__api.m                   Success       496141.2887032853                             9.772190

# %%
# import scipy.io
# import julia
# from julia import Main

# # Initialize Julia and load the required packages
# julia.Julia(compiled_modules=False)
# Main.eval(
# """
# using JuMP, PowerModels, Ipopt
# solver = optimizer_with_attributes(Ipopt.Optimizer, "tol"=>1e-6)
# """
# )

# # List of case files to run (replace with actual .mat file paths or data objects)
# case_files = ["case1.mat", "case2.mat", "case3.mat"]

# # To store the results
# results = []

# # Loop through each case and run the optimization
# for case_file in case_files:
#     # Load the .mat file using scipy.io in Python
#     mat_data = scipy.io.loadmat(case_file)

#     # Pass the .mat data to Julia
#     Main.mat_data = mat_data

#     # Run the AC Optimal Power Flow in Julia and capture the result
#     result = Main.eval('run_ac_opf(mat_data, solver)')

#     # Store the result in the Python results list
#     results.append(result)

# # Now `results` contains the optimization results for each case
# for i, res in enumerate(results):
#     print(f"Result for case {i+1}: {res}")
